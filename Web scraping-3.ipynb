# %%
#Importing libs
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver=webdriver.Chrome(r'C:\Users\Admin\Downloads\chromedriver.exe')
url="https://www.amazon.in/"
driver.get(url)
    
    
    #Look for the class
search_box = driver.find_element_by_xpath("//input[@class='nav-input nav-progressive-attribute']")

a=input('enter the element')
    
    #Write what we be searched#
search_box.send_keys(a)

    #Submit the text
search_box.send_keys(Keys.RETURN)
# Out:
# enter the elementguitar

# %%
a
# Out:
# 'guitar'

# %%
brand=[]
rating=[]
no_ofrating=[]
price=[]
get_by=[]

# %%
start=0
end=3
for page in range(start,end):#for loop for scrapping 3 page\n"
    brands=driver.find_elements_by_xpath("//span[@class='a-size-base-plus a-color-base a-text-normal']")
    for i in brands:
         brand.append(i.text)
    rate=driver.find_elements_by_xpath("//i[@class='a-icon a-icon-star-small a-star-small-4 aok-align-bottom']")
    for i in rate:
         rating.append(i.text)
    nor=driver.find_elements_by_xpath("//span[@class='a-size-base']")
    for i in nor:
         no_ofrating.append(i.text)
    pri=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
    for i in pri:
         price.append(i.text)
    get=driver.find_elements_by_xpath("//span[@class='a-text-bold']")
    for i in get:
         get_by.append(i.text)                                
    nxt_button=driver.find_elements_by_xpath("//li[@class='a-normal']/a")#scraping the list of buttons from the page\n",
    driver.get(nxt_button[page].get_attribute('href'))#getting the link from the list for next page\n",

# %%
brand
# Out:
# ['Musical Instrument GuitarHeavy Padded Guitar Bag With Black Color Cover Fender Soft Fabric 38 Inch. (Z7)',
#  'Musical Instrument GuitarHeavy Padded Guitar Bag With Black Color Cover Fender Soft Fabric 38 Inch. (S9)',
#  'Fender SA 135C 39 Inch 6 String Cutaway Acoustic Guitar - Hardwood Fretboard - Natural',
#  'YEMAHA REGAL THINLINE Export Quality Glossy BLACK 6-String Cut A Way Right Hand Semi Acoustic Guitar With Bag And Free 2 Plecturm',
#  'Fender SA105CEBK Acoustic Guitar',
#  'Havana 41-Inch Cutaway Acoustic Guitar with 5 Band EQ & GT-3 Tuner (Blue)',
#  'Kadence Frontier Series,Black Acoustic Guitar With Die Cast Keys Super Combo (Tuner,Capo,Bag,strap,strings and 3 picks)',
#  'Practical Compact Size Left Hand Portable Guitar, 6 Fret Guitar, Lightweight for Professional Guitar Beginner Guitar',
#  'Carlos Marshello CS39C Acoustic Guitar - Tobacco Black',
#  'Medellin Linden Wood Acoustic Guitar(Sunburst)',
#  'JUAREZ Arpeggio 41 Inch Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, Chrome Die Cast Machine Tuners, Blue',
#  'Kadence Astro Man 36 Inches Electric Guitar, 21 FRETS, ROSEWOOD FRETBOARD, H - S - S PICK UPS Black',
#  'Ibanez MD39C-NT Acoustic Guitar (Natural)',
#  'NP ENTERPRISE 4-String Musical Instrument Guitar, Acoustic Guitar Learning Kids Toy',
#  'JUAREZ Arpeggio 39 Inch Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, Chrome Die Cast Machine Tuners, Natural',
#  'Belear I-280 Couturier Series 38 Inch Blue Spruce Cutaway Acoustic Guitar with Truss Rod Combo with Gig Bag and Picks',
#  'Acoustic Folk Guitar Accessories Kit Including Guitar Strap + Guitar Strings + Finger Protectors(Random Color delivery) for Guitar Beginners',
#  'VB J - 31B Guitar Floor Stand',
#  'FIRANDE Arpeggio 39 Inch Semi-Acoustic Guitar, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, 4 Band EQ, Chrome Die Cast Machine Tuners, Sunburst',
#  'Ibanez Acoustic Guitar MD39C Right Handed Cutaway Guitar - Sunburst With Bag, Belt, Plectrums Complete Pack.',
#  'Martin Smith W-101-WHT-PK Acoustic Guitar Super Kit with Stand (White)',
#  'Kadence Frontier Series Acoustic Guitar with Truss Rod Jumbo 41 inch, Black With Die Cast Keys',
#  'Giuson Venus Blue Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks',
#  'JUAREZ Arpéggio 41 Inch Acoustic Guitar Kit, Spruce Top, Black',
#  'Belear I-280-CBL Couturier 38 Inch Blue Cutaway Acoustic Guitar',
#  "DD Retails 4-String Acoustic Kid's Guitar,Children's Musical Instrument Graphic Designed Guitar",
#  'Juarez JRZ-ST01 6-String Electric Guitar, Right Handed, Full Black, with Case/Bag and Picks',
#  'Belear I-370 38 Inch Red Spruce Dreadnought Acoustic Guitar with Truss Rod With Bag, String, Strap and Picks',
#  'SAAN Life Science 4-string Small Acoustic Guitar Musical Instrument Educational Learning kids Toy for Beginners - 23Inch',
#  'Martin Smith W-101-SB-PK Acoustic Guitar Super Kit with Stand (Sun Burst)',
#  'DEVICE OF URBAN INFOTECH Tuning Peg Silver for Acoustic Guitar Parts Tuners Keys Semi-closed Guitar String Tuning Pegs Tuner Machine Heads Knobs Tuning Keys for Acoustic & Electric Guitar 3R+3L(6 PCS)',
#  'Belear I-370 Vega Series 38 Inch Red Spruce Acoustic Guitar with Truss Rod Combo with Gig Bag and Picks',
#  "Toyvilla™ 6 String Decor Guitar Children's Musical Instrument Educational Toy Guitar for Beginners Kids Childs (Color May Vary)",
#  'Belear I-280 Couturier Series 38 Inch Brown Spruce Cutaway Acoustic Guitar with Truss Rod Combo with Gig Bag and Picks',
#  'DEVICE OF URBAN INOTECH Guitar EQ-7545R 4-Band EQ Equalizer System Acoustic Guitar Preamp With Pickup for Acoustic Guitars - Black',
#  'RockJam RJEG02-SK-BK Electric Guitar Starter Kit (Black)',
#  'Kadence Acoustica 34” Acoustic Guitar A03',
#  'Givsun Topaz Special Blue 6-String Cut A Way Right Hand Acoustic Semi-Electric Guitar With Bag And Free 1 Set String,2 Picks',
#  'JUAREZ Arpeggio 41 Inch Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, Chrome Die Cast Machine Tuners, Blue Sunburst',
#  'Belear I-280-WBR Couturier 38 Inch Brown Cutaway Acoustic Guitar With Bag,Strap,String and Picks',
#  'Luximal 4 String Musical Guitar For Kids Instrument Acoustic Learning Educational Small Toy For Child with Ability Random Brown Color Best Gift For Boys & Girls',
#  'Hovner Luna Rosewood Fretboard Blue Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks (Blue)',
#  'Fender CD 60 Dread V3 DS 6 String Acoustic Guitar - Walnut Fretboard-Sunburst',
#  'Belear I-370 Vega 38 Inch Red Dreadnought Acoustic Guitar',
#  'DEVICE OF URBAN INFOTECH 360 degree Rotational Electronic Highly Accurate Clip-on Digital Tuner Easy to Use for Acoustic and Electric Guitar Bass Violin Ukulele with 5 Pcs Picks (Design May Vary)',
#  'JUAREZ Arpeggio 39 Inch Semi-Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, 4 Band EQ, Chrome Die Cast Machine Tuners, Sunburst',
#  'Martin Smith W-101-Bl-PK Acoustic Guitar Super Kit with Stand (Blue)',
#  'Havana AAG-39 Inch Cutaway Acoustic Guitar (Cherry Burst)',
#  'Kadence Acoustica 40” Acoustic Guitar A04 Natural',
#  'KHODIYAR 4-String Musical Instrument Guitar, Acoustic Guitar Learning Kids Toy',
#  'Intern INT-38C Acoustic Guitar Kit (Sunburst)',
#  'GUITAR BRO - COMBO (Blue Acoustic Guitar for Beginner, Guitar Learning Kit, Song Book, Video Lectures, Accessories like Pick, Bag)',
#  'Musical Instrument GuitarHeavy Padded Guitar Bag With Black Color Cover Fender Soft Fabric 38 Inch. (Z4)',
#  'GUITAR BRO - Guitar Learning Combo (30 Day Learning Kit + 4 Live 1-on-1 Classes (each class is 20 mins, Access Key Inside the Kit), Acoustic Guitars Accessories, Picks, Songbook, Videos)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juarez JRZ38C Acoustic Guitar, 38 Inch Cutaway with Bag (TBS Transparent Blue Sunburst)',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
#  'JUAREZ JRZ38C Right Handed Acoustic Guitar with Bag, Strings, Pick and Strap (Natural, 6 Strings)',
#  'Juarez Acoustic Guitar, 38 Inch Cutaway with Pick Guard, 38CPG with Bag, Strings, Pick and Strap, Black',
#  'Kadence Frontier Series,Black Semi Acoustic Guitar With Die Cast Keys (Bag,Strap,Strings And 3 Picks Stand)',
#  'Intern 38-inch Cutaway Design Black Acoustic Guitar with Picks & Carry Bag',
#  'Intern INT-38C-SB-G Cutaway Right Handed Acoustic Guitar Kit, With Bag, Strings, Pick And Strap (Sunburst, 6 Strings)',
#  'Giuson Venus Black 41 Inch Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks by K-Retail',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys,Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (black & stand)',
#  'Jixing JXNG-BLK-SC1,Black Acoustic Guitar with Kadence Foldable Guitar Stand,Kadence Tuner,Kadence String,Kadence Strap,Kadence 3 Picks,Kadence Bag & Kadence Capo (Super Combo)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Red',
#  '',
#  '',
#  'Kadence Frontier Series, Acoustic Guitar With/Wihtout EQ Die Cast Keys Combo (Bag,strap,strings and 3 picks) (Brown, Acoustic)',
#  'Belear K-610NAT Vega Series 41 Inch Natural Spruce Dreadnought Acoustic Guitar Combo with Gig Bag and Picks',
#  'YAMAHA FS80C NATURAL CONCERT CUTAWAY GUITAR',
#  'JUAREZ 41 INCH GUITAR JRZ41VG/BK, BLACK',
#  'Musical Instrument GuitarHeavy Padded Guitar Bag With Black Color Cover Fender Soft Fabric 38 Inch. (S7)',
#  'Green : Aroma AHF-03 Portable Guitar Bass Piano Hand and Finger Exerciser Medium Tension Hand Grip Trainer',
#  'Laxmi Musical Electronics - Acoustic Pickup for veena, Violin, Guitar and All Acoustic String Instruments',
#  'DEVICE OF URBAN INFOTECH Tuning Peg Silver for Acoustic Guitar Parts Tuners Keys Semi-closed Guitar String Tuning Pegs Tuner Machine Heads Knobs Tuning Keys for Acoustic & Electric Guitar 3R+3L(6 PCS)',
#  'Kadence Frontier Series,Black Acoustic Guitar With Die Cast Keys Combo (Bag,strap,strings and 3 picks)',
#  'Hovner Venus Natural 6-String Cut-A-Way Right Hand Acoustic Semi-Electric Guitar with Bag and Free 1 Set String, 2 Picks.',
#  'JUAREZ JRZ38CTR/BK 38 Inch Acoustic Guitar with Dual Action Truss Rod, Bag, Picks, Allen Key, Extra String Set, Black',
#  'Medellin MED-BLU-C Linden Wood Acoustic Guitar',
#  'Juarez Acoustic Guitar, [ LEFT HANDED] 38 Inch Cutaway, 38CL/BK with Bag, Strings, Pick and Strap, Black',
#  'JUAREZ JRZ38C Right Handed Acoustic Guitar (Sunburst, 6 Strings)',
#  'Our Store 24" 6 String Decor Guitar Children\'s Musical Instrument Educational Toy Guitar for Beginners Kids Child (Color May Vary)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, JRZ38C with Bag, Strings, Pick and Strap, Blue',
#  'Kordz 150 Smoky Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks V3',
#  'Juârez JRZ38C/MAH 6 Strings Acoustic Guitar 38 Inch Cutaway, Right Handed, Mahogany with Bag, Strings, Picks and Strap',
#  'Juarez Acoustic Guitar, 38 Inch Cutaway, 38CMB with Bag, Strings, Pick and Strap, Matte Black',
#  '41"das musical acoustic venus guitar. cover, string, belt, 2plectrums.',
#  'Blueberry B-40, 40" Acoustic Guitar Kit with Bag,Belt, One Pack Strings & Picks (Black)',
#  'Flexible 21Inch Wood Hawaii Kids Guitar, Mini Guitar Ukulele Toy, for Beginner Children Boys and Girls(Purple Elf)',
#  "KINDRED™ Musical Guitar,4-String Musical Instrument Learning Toy,Children's Educational Musical Instrument Toy for Kids, Child for Learning with Brown Color Best Gift for Boys & Girls (18 Inches)",
#  "Crizer 4 String Guitar Children's Musical Instrument Educational Toy Guitar Ukulele Instruments Beginner Musical Sound Toys Best Gift for Children",
#  'JUAREZ Fiésta 41 Inch Acoustic Guitar with Dual Action Truss Rod, 21 Frets Rosewood Fretboard & Bridge, Padded 5mm Cotton Bag, Cotton Strap, 2 Picks, Allen Key, Extra String Set, Natural',
#  'Belear I-280 Couturier Series 38 Inch Black Spruce Cutaway Acoustic Guitar Combo with Gig Bag and Picks',
#  'JUAREZ Fiésta 41 Inch Acoustic Guitar with Dual Action Truss Rod, 21 Frets Rosewood Fretboard & Bridge, Padded 5mm Cotton Bag, Cotton Strap, 2 Picks, Allen Key, Extra String Set, Brown',
#  'Blueberry B-40 IN, Trussrod Acoustic Guitar Kit with Bag,Belt, One Pack Strings & Picks (Blue)',
#  'Belear K-610MAH Vega Series King Size Jumbo Natural Okoume Wood Dreadnought Acoustic Guitar Combo with Gig Bag and Picks',
#  'Hovner 215 Dark Green F-Cut Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks By V3',
#  'Kordz Luana Natural Wooden 41 Inch Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks',
#  'Divinext Audio Interface AMP Guitar Effects Pedal for iPhone/iPad',
#  'Juârez JRZ38C/ASH 6 Strings Acoustic Guitar 38 Inch Cutaway, Right Handed, Ash with Bag, Strings, Picks and Strap',
#  'JUAREZ Arpeggio 39 Inch Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, Chrome Die Cast Machine Tuners, Blue Sunburst',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Natural',
#  'Kadence AstroMan Electric Guitar, 21 FRETS, ROSEWOOD FRETBOARD, H - S - S PICK UPS Black combo with Bag, Guitar strap,guitar cable and Picks',
#  'JUAREZ 38 Inch Acoustic Guitar with Dual Action Truss Rod, Bag, Picks, Allen Key, Extra String Set, Natural',
#  'JUAREZ 41 INCH GUITAR JRZ41NG/BK, BLACK',
#  "CBOX 4 String Guitar Children's Musical Instrument Educational Toy Guitar Ukulele Instruments Beginner Musical Sound Toys Best Gift for Children(Multi-Color)",
#  'Vault EA20 Learn to Play Guitar Kit with Ebook, Bag, Strings, Straps, Picks, String winder & Polishing Cloth - 40 inch Cutaway Acoustic Guitar',
#  'DEVICE OF URBAN INFOTECH Tuning Peg Silver for Acoustic Guitar Parts Tuners Keys Semi-closed Guitar String Tuning Pegs Tuner Machine Heads Knobs Tuning Keys for Acoustic & Electric Guitar 3R+3L (6PCS)',
#  'Musical Instrument GuitarHeavy Padded Guitar Bag With Black Color Cover Fender Soft Fabric 38 Inch. (Z7)',
#  'Musical Instrument GuitarHeavy Padded Guitar Bag With Black Color Cover Fender Soft Fabric 38 Inch. (S9)',
#  'Fender SA 135C 39 Inch 6 String Cutaway Acoustic Guitar - Hardwood Fretboard - Natural',
#  'YEMAHA REGAL THINLINE Export Quality Glossy BLACK 6-String Cut A Way Right Hand Semi Acoustic Guitar With Bag And Free 2 Plecturm',
#  'Fender SA105CEBK Acoustic Guitar',
#  'Havana 41-Inch Cutaway Acoustic Guitar with 5 Band EQ & GT-3 Tuner (Blue)',
#  'Kadence Frontier Series,Black Acoustic Guitar With Die Cast Keys Super Combo (Tuner,Capo,Bag,strap,strings and 3 picks)',
#  'Practical Compact Size Left Hand Portable Guitar, 6 Fret Guitar, Lightweight for Professional Guitar Beginner Guitar',
#  'Carlos Marshello CS39C Acoustic Guitar - Tobacco Black',
#  'Medellin Linden Wood Acoustic Guitar(Sunburst)',
#  'JUAREZ Arpeggio 41 Inch Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, Chrome Die Cast Machine Tuners, Blue',
#  'Kadence Astro Man 36 Inches Electric Guitar, 21 FRETS, ROSEWOOD FRETBOARD, H - S - S PICK UPS Black',
#  'Ibanez MD39C-NT Acoustic Guitar (Natural)',
#  'NP ENTERPRISE 4-String Musical Instrument Guitar, Acoustic Guitar Learning Kids Toy',
#  'JUAREZ Arpeggio 39 Inch Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, Chrome Die Cast Machine Tuners, Natural',
#  'Belear I-280 Couturier Series 38 Inch Blue Spruce Cutaway Acoustic Guitar with Truss Rod Combo with Gig Bag and Picks',
#  'Acoustic Folk Guitar Accessories Kit Including Guitar Strap + Guitar Strings + Finger Protectors(Random Color delivery) for Guitar Beginners',
#  'VB J - 31B Guitar Floor Stand',
#  'FIRANDE Arpeggio 39 Inch Semi-Acoustic Guitar, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, 4 Band EQ, Chrome Die Cast Machine Tuners, Sunburst',
#  'Ibanez Acoustic Guitar MD39C Right Handed Cutaway Guitar - Sunburst With Bag, Belt, Plectrums Complete Pack.',
#  'Martin Smith W-101-WHT-PK Acoustic Guitar Super Kit with Stand (White)',
#  'Kadence Frontier Series Acoustic Guitar with Truss Rod Jumbo 41 inch, Black With Die Cast Keys',
#  'Giuson Venus Blue Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks',
#  'JUAREZ Arpéggio 41 Inch Acoustic Guitar Kit, Spruce Top, Black',
#  'Belear I-280-CBL Couturier 38 Inch Blue Cutaway Acoustic Guitar',
#  "DD Retails 4-String Acoustic Kid's Guitar,Children's Musical Instrument Graphic Designed Guitar",
#  'Juarez JRZ-ST01 6-String Electric Guitar, Right Handed, Full Black, with Case/Bag and Picks',
#  'Belear I-370 38 Inch Red Spruce Dreadnought Acoustic Guitar with Truss Rod With Bag, String, Strap and Picks',
#  'SAAN Life Science 4-string Small Acoustic Guitar Musical Instrument Educational Learning kids Toy for Beginners - 23Inch',
#  'Martin Smith W-101-SB-PK Acoustic Guitar Super Kit with Stand (Sun Burst)',
#  'DEVICE OF URBAN INFOTECH Tuning Peg Silver for Acoustic Guitar Parts Tuners Keys Semi-closed Guitar String Tuning Pegs Tuner Machine Heads Knobs Tuning Keys for Acoustic & Electric Guitar 3R+3L(6 PCS)',
#  'Belear I-370 Vega Series 38 Inch Red Spruce Acoustic Guitar with Truss Rod Combo with Gig Bag and Picks',
#  "Toyvilla™ 6 String Decor Guitar Children's Musical Instrument Educational Toy Guitar for Beginners Kids Childs (Color May Vary)",
#  'Belear I-280 Couturier Series 38 Inch Brown Spruce Cutaway Acoustic Guitar with Truss Rod Combo with Gig Bag and Picks',
#  'DEVICE OF URBAN INOTECH Guitar EQ-7545R 4-Band EQ Equalizer System Acoustic Guitar Preamp With Pickup for Acoustic Guitars - Black',
#  'RockJam RJEG02-SK-BK Electric Guitar Starter Kit (Black)',
#  'Kadence Acoustica 34” Acoustic Guitar A03',
#  'Givsun Topaz Special Blue 6-String Cut A Way Right Hand Acoustic Semi-Electric Guitar With Bag And Free 1 Set String,2 Picks',
#  'JUAREZ Arpeggio 41 Inch Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, Chrome Die Cast Machine Tuners, Blue Sunburst',
#  'Belear I-280-WBR Couturier 38 Inch Brown Cutaway Acoustic Guitar With Bag,Strap,String and Picks',
#  'Luximal 4 String Musical Guitar For Kids Instrument Acoustic Learning Educational Small Toy For Child with Ability Random Brown Color Best Gift For Boys & Girls',
#  'Hovner Luna Rosewood Fretboard Blue Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks (Blue)',
#  'Fender CD 60 Dread V3 DS 6 String Acoustic Guitar - Walnut Fretboard-Sunburst',
#  'Belear I-370 Vega 38 Inch Red Dreadnought Acoustic Guitar',
#  'DEVICE OF URBAN INFOTECH 360 degree Rotational Electronic Highly Accurate Clip-on Digital Tuner Easy to Use for Acoustic and Electric Guitar Bass Violin Ukulele with 5 Pcs Picks (Design May Vary)',
#  'JUAREZ Arpeggio 39 Inch Semi-Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, 4 Band EQ, Chrome Die Cast Machine Tuners, Sunburst',
#  'Martin Smith W-101-Bl-PK Acoustic Guitar Super Kit with Stand (Blue)',
#  'Havana AAG-39 Inch Cutaway Acoustic Guitar (Cherry Burst)',
#  'Kadence Acoustica 40” Acoustic Guitar A04 Natural',
#  'KHODIYAR 4-String Musical Instrument Guitar, Acoustic Guitar Learning Kids Toy']

# %%
get_by
# Out:
# ['Monday, May 3',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Friday, May 21',
#  'Tuesday, May 25',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Tuesday, May 4',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 19',
#  'Saturday, May 22',
#  'Wednesday, April 28',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 5',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 5',
#  'Wednesday, May 5',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Tuesday, May 4',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 5',
#  'Wednesday, May 5',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 5',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Tuesday, May 4',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Sunday, May 9',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Friday, April 30',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 5',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Tuesday, May 4',
#  'Monday, May 3',
#  'Wednesday, May 19',
#  'Saturday, May 22',
#  'Wednesday, May 5',
#  'Tuesday, May 4',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 5',
#  'Wednesday, May 5',
#  'Saturday, May 8',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Friday, May 21',
#  'Tuesday, May 25',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Tuesday, May 4',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 19',
#  'Saturday, May 22',
#  'Wednesday, April 28',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 5',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 5',
#  'Wednesday, May 5',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Tuesday, May 4',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 5',
#  'Wednesday, May 5',
#  'Monday, May 3',
#  'Monday, May 3',
#  'Wednesday, May 5',
#  'Friday, April 30',
#  'Monday, May 3',
#  'Friday, April 30',
#  'Tuesday, May 4']

# %%
no_ofrating
# Out:
# ['101',
#  '1',
#  '245',
#  '1',
#  '430',
#  '1',
#  '3',
#  '2',
#  '218',
#  '7',
#  '8',
#  '13',
#  '13',
#  '4',
#  '5',
#  '139',
#  '3',
#  '14',
#  '3',
#  '1',
#  '83',
#  '1',
#  '3',
#  '1',
#  '4',
#  '194',
#  '98',
#  '1',
#  '143',
#  '5,128',
#  '18',
#  '6',
#  '8,957',
#  '5,128',
#  '3,078',
#  '742',
#  '2,069',
#  '152',
#  '275',
#  '992',
#  '677',
#  '123',
#  '393',
#  '430',
#  '8,957',
#  '5,128',
#  '',
#  '',
#  '571',
#  '35',
#  '3',
#  '2',
#  '3',
#  '401',
#  '5',
#  '80',
#  '347',
#  '429',
#  '3,274',
#  '1',
#  '859',
#  '149',
#  '151',
#  '31',
#  '3',
#  '34',
#  '17',
#  '13',
#  '7',
#  '1',
#  '84',
#  '95',
#  '169',
#  '2',
#  '423',
#  '44',
#  '15',
#  '4',
#  '2',
#  '101',
#  '1',
#  '245',
#  '1',
#  '430',
#  '1',
#  '3',
#  '2',
#  '218',
#  '7',
#  '8',
#  '13',
#  '13',
#  '4',
#  '5',
#  '139',
#  '3',
#  '14',
#  '3',
#  '1',
#  '83',
#  '1',
#  '3',
#  '1',
#  '4',
#  '194',
#  '98',
#  '1',
#  '143']

# %%
import pandas as pd
df=pd.DataFrame({"Brand":brand[0:10],
                "rating":rating[0:10],
                "no of rating":no_ofrating[0:10],
                 "price":price[0:10],
                 "get it by":get_by[0:10]
                })

# %% [markdown]
# # 3. Write a python program to access the search bar and search button on images.google.com and scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’

# %%
import selenium
import pandas as pd
from selenium import webdriver

# %%
driver=webdriver.Chrome(r'C:\Users\Admin\Downloads\chromedriver.exe')

# %%
url="https://images.google.com/?gws_rd=ssl"
driver.get(url)

# %%
search_bar = driver.find_element_by_xpath('//*[@id=\"sbtc\"]/div/div[2]/input')   
search_bar.send_keys("fruits")       
search_button = driver.find_element_by_xpath('//*[@id=\"sbtc\"]/button')   
search_button.click()

# %%
for i in range(500):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

# %%
img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
len(img_urls)
# Out:
# 0

# %%
for i in range(len(img_urls)):
    if i >= 100:
        break
        print("Downloading {0} of {1} images".format(i,100))
        response= requests.get(img_urls[i])
        file = open("H:/Flip ROBO/banana/img"+str(i)+".jpg\", \"wb")
        file.write(response.content)

# %%
source

# %%
url="https://images.google.com/?gws_rd=ssl"
driver.get(url)
from selenium.webdriver.common.keys import Keys
search_box = driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")


    
    #Write what we be searched#
search_box.send_keys('machine learning')

    #Submit the text
search_box.send_keys(Keys.RETURN)

# %%
machine=[]
ml=driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
for i in ml:
    machine.append(i)

# %%
machine
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="7422a2e2-8c6d-49a9-9533-2c1429e6e313")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="c4e389e0-ff38-4380-a6e0-c324a6b4747f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="76c44363-1775-4bf0-82c1-9c7d5a7f247b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="b2d6ec4e-747d-42a5-85ae-140fd3b4da29")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="a6c89ba5-9a6e-4555-90b2-1dcc2f2be009")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="8fd26f39-061a-4355-a520-6cab0a111ced")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="c93e84a7-55b9-4585-8eb8-6709587019a1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="138a7cf2-338b-487b-a696-6b939f10c169")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="d9ac16a3-089b-4de8-8ba4-7451bebd90ed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="f540089a-c135-41fd-a1ae-2b2ecdaed576")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="048d4340-3b01-4215-9873-4d24df26ab4e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="0c599e50-4100-4ab3-b04c-cbf2598b6deb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="761440c2-cb37-47f9-8e1b-62663540ab38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="cd929088-1dbc-48f0-a847-5ff97de04712")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="ed6d2507-41dc-4af5-bcb1-ef593b86e996")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="71d1d4d9-0463-45a8-a15b-7800e18e2d4d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="648c6432-5671-49d8-b940-c4a671471d96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="f7da8457-f274-4682-adbf-4b7540bf8016")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="5f6825bf-99b5-4878-8890-17249f526384")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="70f18c18-fc57-4653-be83-4bece02664b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="cd7a0948-418e-41ae-b254-1122de072a51")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="de8b5afc-d564-4d2f-a148-148a049b6332")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="91f7cfdc-7451-4bfe-912d-3a1c4325ce99")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="63a9472e-2269-43aa-a64a-912875be8644")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="33a31493-d14c-4371-877e-58b8eb6687b7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="477b2c1f-f834-452d-a5dc-ed8aab0de5a5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="ed09a629-65ca-46d0-9042-dce119172892")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="84173361-4279-4bb3-bdd3-c8a0b01cfc8c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="351d1454-adcf-49fc-9f66-30a9a50dfbfa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="de10e21c-7ac7-4412-881e-3e34f9bd3a62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="6005b113-ea7b-4d8a-bfca-3db1b96556b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="4696eb43-d1b3-4dbb-94c4-f2801bfccacf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="8005773e-bdf5-4d3d-8e7c-5b7f22b26aeb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="ff490791-d751-4cc6-b887-7f8cd6719899")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="da11dd8c-9d64-44e2-bbda-c76b40317993")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="a26465e8-630a-4116-8571-cf601df3e2a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="058dc436-4526-4a56-8710-bf979cc07d5b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="aa71c9f2-4f1a-48a7-b57a-020d329fcf07")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="e400bb83-06b4-49d2-a280-ad790409e1c9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="4407f1f1-0ad3-4ac8-979f-96b4f3c73db8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="349d17d9-61f8-4201-ac1e-813af616cb6e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="96087976-920c-4468-a720-fd1f295a8e38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="deef5fdc-3c8a-430a-b4f5-955a3752444b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="68757c9b-5ee5-4f2f-a2a5-a504cebd8129")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="913aff95-54ad-453a-81db-1546b9c636c6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="97d7b0e2-a385-4f95-a2d4-7f99a0fefce8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="11942ef3-2c39-4691-8579-05ceb72dc917")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="f6eb8afe-9830-48be-abb4-10adae341959")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b0fcb50fd86c6cbe4ce1f5a8490566ba", element="9b7ca489-69aa-4fe3-9bb5-719bdbcfcf46")>]

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
url="https://www.flipkart.com/"
driver.get(url)

# %%
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
prod = input(" Enter the name of the mobile phone you want to search :")
time.sleep(3)
try:
    login_X_button = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z\"]')                   
    login_X_button.click()
except NoSuchElementException:
    print("No Login page")
search_bar = driver.find_element_by_xpath('//*[@id=\"container\"]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')    
search_bar.clear()              
search_bar.send_keys(prod)      
search_button = driver.find_element_by_xpath('//button[@class="L0Z3Pu\"]')   
search_button.click()
# Out:
#  Enter the name of the mobile phone you want to search :samsung

# %%
flip_urls = []
urls = driver.find_elements_by_xpath('//a[@class=\"_1fQZEK\"]')
for url in urls:
    flip_urls.append(url.get_attribute("href"))

# %%
len(flip_urls)
# Out:
# 24

# %%
flip_dict = {}
flip_dict["Brand"] = []
flip_dict["Smartphone"] = []
flip_dict["Colour"] = []
flip_dict["RAM"] = []
flip_dict["Storage(ROM)"] = []
flip_dict["Primary Camera"] = []
flip_dict["Secondary Camera"] = []
flip_dict["Display Size"] = []
flip_dict["Display Resolution"] = []
flip_dict["Processor"] = []
flip_dict["Processor Cores"] = []
flip_dict["Battery Capacity"] = []
flip_dict["Battery Type"] = []
flip_dict["Price"] = []
flip_dict["URL"] = []

# %%
for url in flip_urls:
    driver.get(url)    
    print("Scraping URL = ", url)
    flip_dict['URL'].append(url)                                                         
    time.sleep(2)
try:
    read_more = driver.find_element_by_xpath('//button[@class=\"_2KpZ6l _1FH0tX\"]')     
    read_more.click()
except NoSuchElementException:
        print("Exception Occured. Moving to next page")

try:
    brand = driver.find_element_by_xpath('//span[@class="B_NuCI"]')      
    flip_dict["Brand"].append(brand.text.split()[0])
except NoSuchElementException:
          flip_dict['Brand'].append('-')
 
try:
    price = driver.find_element_by_xpath('//div[@class=\"_30jeq3 _16Jk6d\"]')     
    flip_dict['Price'].append(price.text)
except NoSuchElementException:
       flip_dict['Price'].append('-')
   
try:
    name = driver.find_element_by_xpath('//div[@class=\"_3k-BhJ\"][1]/table/tbody/tr[3]/td[2]/ul/li')     
    flip_dict['Smartphone'].append(name.text)
except NoSuchElementException:
            flip_dict['Smartphone'].append('-')
    
try:
    color = driver.find_element_by_xpath('//div[@class=\"_3k-BhJ\"][1]/table/tbody/tr[4]/td[2]/ul/li')      
    flip_dict['Colour'].append(color.text)
except NoSuchElementException:
            flip_dict['Colour'].append('-')
     
try:
    disp_chk = driver.find_element_by_xpath('//div[@class=\"_3k-BhJ\"][2]/div')
    if disp_chk.text != "Display Features" : raise NoSuchElementException
    disp_size = driver.find_element_by_xpath('//div[@class=\"_3k-BhJ\"][2]/table[1]/tbody/tr[1]/td[2]/ul/li')  
    flip_dict['Display Size'].append(disp_size.text)
except NoSuchElementException:
    flip_dict['Display Resolution'].append('-')
# Out:
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f12-sea-green-64-gb/p/itm4d3582cd695fd?pid=MOBGFG794YPQ9RAE&lid=LSTMOBGFG794YPQ9RAEGUPPTW&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG794YPQ9RAE.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f12-celestial-black-64-gb/p/itmaae10b8db3909?pid=MOBGFG79FUDPXZXQ&lid=LSTMOBGFG79FUDPXZXQH5PM6N&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79FUDPXZXQ.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f12-celestial-black-128-gb/p/itm794cccf7936c0?pid=MOBGFG79NWFGVZRY&lid=LSTMOBGFG79NWFGVZRYB7JYVS&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79NWFGVZRY.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f12-sea-green-128-gb/p/itm632faa123e085?pid=MOBGFG79ZZFRGZ7U&lid=LSTMOBGFG79ZZFRGZ7ULB8HLU&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79ZZFRGZ7U.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f12-sky-blue-64-gb/p/itm0319ce24f74aa?pid=MOBGFG79BVGDHGWV&lid=LSTMOBGFG79BVGDHGWVGF2CRI&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79BVGDHGWV.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f12-sky-blue-128-gb/p/itmbe3d99dae33a0?pid=MOBGFG79BPTJWHKS&lid=LSTMOBGFG79BPTJWHKSO3JF0R&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79BPTJWHKS.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f41-fusion-green-64-gb/p/itmce548f0500d55?pid=MOBFV5PWXJRV9WZZ&lid=LSTMOBFV5PWXJRV9WZZSWCHLG&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWXJRV9WZZ.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f41-fusion-blue-64-gb/p/itmcdc5e93b44d55?pid=MOBFV5PWHRYTYYJF&lid=LSTMOBFV5PWHRYTYYJFLE0GZO&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWHRYTYYJF.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f41-fusion-black-64-gb/p/itmde5e6cd41fc4d?pid=MOBFV5PWGEVNPWS2&lid=LSTMOBFV5PWGEVNPWS2VG4KHD&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWGEVNPWS2.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f41-fusion-green-128-gb/p/itma41850a2f9e19?pid=MOBFV5PWEX7WJS7R&lid=LSTMOBFV5PWEX7WJS7RBAY0T5&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWEX7WJS7R.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-guru-fm-plus-sm-b110e-d/p/itmf4w45bqfdfnef?pid=MOBE996SKVGGH94Q&lid=LSTMOBE996SKVGGH94QA0OBOX&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBE996SKVGGH94Q.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-guru-1200/p/itmeb6w98vmhffjy?pid=MOBDA2CFCQ6CFHTZ&lid=LSTMOBDA2CFCQ6CFHTZKLVHX9&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBDA2CFCQ6CFHTZ.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f41-fusion-blue-128-gb/p/itm4769d0667cdf9?pid=MOBFV5PWG5MGD4CF&lid=LSTMOBFV5PWG5MGD4CFZ8YQJZ&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWG5MGD4CF.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-guru-1200/p/itmeb6wxfgbxphcw?pid=MOBDADMTTV7HXGTF&lid=LSTMOBDADMTTV7HXGTFK8JMQC&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBDADMTTV7HXGTF.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-guru-music-2/p/itmdz9am8xehucbx?pid=MOBDZ9AMJ472Y9MW&lid=LSTMOBDZ9AMJ472Y9MWHCAZNO&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBDZ9AMJ472Y9MW.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f41-fusion-black-128-gb/p/itme88b8042fe996?pid=MOBFV5PWUHRY2MZZ&lid=LSTMOBFV5PWUHRY2MZZXXFGKQ&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWUHRY2MZZ.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-guru-music-2/p/itme9tgwmffh64cy?pid=MOBE9TGVE7ZBRAEN&lid=LSTMOBE9TGVE7ZBRAENZIQX1Q&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBE9TGVE7ZBRAEN.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f02s-diamond-black-64-gb/p/itm9bd7eed56f2cf?pid=MOBGFG79NYAKZFH5&lid=LSTMOBGFG79NYAKZFH57TJ6C3&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79NYAKZFH5.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-f02s-diamond-blue-32-gb/p/itm971ab77f825aa?pid=MOBGFG79GQGAYVNV&lid=LSTMOBGFG79GQGAYVNVU1F9M9&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79GQGAYVNV.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-guru-music-2/p/itme9zfpajsaffyj?pid=MOBE9NT8G2QRT2Z4&lid=LSTMOBE9NT8G2QRT2Z41SMXRY&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBE9NT8G2QRT2Z4.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-m12-blue-64-gb/p/itm062b6548d8904?pid=MOBGFG8GCPEGKGF4&lid=LSTMOBGFG8GCPEGKGF4UX7TBP&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG8GCPEGKGF4.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-guru-fm-plus-sm-b110e-d/p/itmew8srgqg73y6p?pid=MOBEA9SJWSGMFVPP&lid=LSTMOBEA9SJWSGMFVPP8XIDUP&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBEA9SJWSGMFVPP.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-m01-core-black-16-gb/p/itmcc59efe93b40b?pid=MOBFUAEBGZKRFGHX&lid=LSTMOBFUAEBGZKRFGHXXLCQJR&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFUAEBGZKRFGHX.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de
# Scraping URL =  https://www.flipkart.com/samsung-guru-1200/p/itme6gz6jczu5ygz?pid=MOBDADKKAEHYYA3G&lid=LSTMOBDADKKAEHYYA3GQQWSFH&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBDADKKAEHYYA3G.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de

# %%
len(flip_dict["Brand"])
# Out:
# 1

# %%
flip_dict
# Out:
# {'Brand': ['SAMSUNG'],
#  'Smartphone': ['Guru 1200'],
#  'Colour': ['White'],
#  'RAM': [],
#  'Storage(ROM)': [],
#  'Primary Camera': [],
#  'Secondary Camera': [],
#  'Display Size': ['3.81 cm (1.5 inch)'],
#  'Display Resolution': [],
#  'Processor': [],
#  'Processor Cores': [],
#  'Battery Capacity': [],
#  'Battery Type': [],
#  'Price': ['₹1,335'],
#  'URL': ['https://www.flipkart.com/samsung-galaxy-f12-sea-green-64-gb/p/itm4d3582cd695fd?pid=MOBGFG794YPQ9RAE&lid=LSTMOBGFG794YPQ9RAEGUPPTW&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG794YPQ9RAE.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f12-celestial-black-64-gb/p/itmaae10b8db3909?pid=MOBGFG79FUDPXZXQ&lid=LSTMOBGFG79FUDPXZXQH5PM6N&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79FUDPXZXQ.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f12-celestial-black-128-gb/p/itm794cccf7936c0?pid=MOBGFG79NWFGVZRY&lid=LSTMOBGFG79NWFGVZRYB7JYVS&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79NWFGVZRY.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f12-sea-green-128-gb/p/itm632faa123e085?pid=MOBGFG79ZZFRGZ7U&lid=LSTMOBGFG79ZZFRGZ7ULB8HLU&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79ZZFRGZ7U.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f12-sky-blue-64-gb/p/itm0319ce24f74aa?pid=MOBGFG79BVGDHGWV&lid=LSTMOBGFG79BVGDHGWVGF2CRI&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79BVGDHGWV.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f12-sky-blue-128-gb/p/itmbe3d99dae33a0?pid=MOBGFG79BPTJWHKS&lid=LSTMOBGFG79BPTJWHKSO3JF0R&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79BPTJWHKS.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f41-fusion-green-64-gb/p/itmce548f0500d55?pid=MOBFV5PWXJRV9WZZ&lid=LSTMOBFV5PWXJRV9WZZSWCHLG&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWXJRV9WZZ.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f41-fusion-blue-64-gb/p/itmcdc5e93b44d55?pid=MOBFV5PWHRYTYYJF&lid=LSTMOBFV5PWHRYTYYJFLE0GZO&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWHRYTYYJF.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f41-fusion-black-64-gb/p/itmde5e6cd41fc4d?pid=MOBFV5PWGEVNPWS2&lid=LSTMOBFV5PWGEVNPWS2VG4KHD&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWGEVNPWS2.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f41-fusion-green-128-gb/p/itma41850a2f9e19?pid=MOBFV5PWEX7WJS7R&lid=LSTMOBFV5PWEX7WJS7RBAY0T5&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWEX7WJS7R.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-guru-fm-plus-sm-b110e-d/p/itmf4w45bqfdfnef?pid=MOBE996SKVGGH94Q&lid=LSTMOBE996SKVGGH94QA0OBOX&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBE996SKVGGH94Q.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-guru-1200/p/itmeb6w98vmhffjy?pid=MOBDA2CFCQ6CFHTZ&lid=LSTMOBDA2CFCQ6CFHTZKLVHX9&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBDA2CFCQ6CFHTZ.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f41-fusion-blue-128-gb/p/itm4769d0667cdf9?pid=MOBFV5PWG5MGD4CF&lid=LSTMOBFV5PWG5MGD4CFZ8YQJZ&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWG5MGD4CF.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-guru-1200/p/itmeb6wxfgbxphcw?pid=MOBDADMTTV7HXGTF&lid=LSTMOBDADMTTV7HXGTFK8JMQC&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBDADMTTV7HXGTF.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-guru-music-2/p/itmdz9am8xehucbx?pid=MOBDZ9AMJ472Y9MW&lid=LSTMOBDZ9AMJ472Y9MWHCAZNO&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBDZ9AMJ472Y9MW.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f41-fusion-black-128-gb/p/itme88b8042fe996?pid=MOBFV5PWUHRY2MZZ&lid=LSTMOBFV5PWUHRY2MZZXXFGKQ&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFV5PWUHRY2MZZ.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-guru-music-2/p/itme9tgwmffh64cy?pid=MOBE9TGVE7ZBRAEN&lid=LSTMOBE9TGVE7ZBRAENZIQX1Q&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBE9TGVE7ZBRAEN.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f02s-diamond-black-64-gb/p/itm9bd7eed56f2cf?pid=MOBGFG79NYAKZFH5&lid=LSTMOBGFG79NYAKZFH57TJ6C3&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79NYAKZFH5.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-f02s-diamond-blue-32-gb/p/itm971ab77f825aa?pid=MOBGFG79GQGAYVNV&lid=LSTMOBGFG79GQGAYVNVU1F9M9&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG79GQGAYVNV.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-guru-music-2/p/itme9zfpajsaffyj?pid=MOBE9NT8G2QRT2Z4&lid=LSTMOBE9NT8G2QRT2Z41SMXRY&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBE9NT8G2QRT2Z4.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-galaxy-m12-blue-64-gb/p/itm062b6548d8904?pid=MOBGFG8GCPEGKGF4&lid=LSTMOBGFG8GCPEGKGF4UX7TBP&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBGFG8GCPEGKGF4.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-guru-fm-plus-sm-b110e-d/p/itmew8srgqg73y6p?pid=MOBEA9SJWSGMFVPP&lid=LSTMOBEA9SJWSGMFVPP8XIDUP&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBEA9SJWSGMFVPP.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-m01-core-black-16-gb/p/itmcc59efe93b40b?pid=MOBFUAEBGZKRFGHX&lid=LSTMOBFUAEBGZKRFGHXXLCQJR&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBFUAEBGZKRFGHX.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de',
#   'https://www.flipkart.com/samsung-guru-1200/p/itme6gz6jczu5ygz?pid=MOBDADKKAEHYYA3G&lid=LSTMOBDADKKAEHYYA3GQQWSFH&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=SEARCH&iid=04f74418-c0ec-442d-96d3-454e9e804867.MOBDADKKAEHYYA3G.SEARCH&ppt=hp&ppn=homepage&ssid=1qb00x26800000001619447719288&qH=fe546279a62683de']}

# %% [markdown]
# # Q5. 5.\tWrite a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\Admin\Downloads\chromedriver.exe')

# %%
driver.get("https://www.google.co.in/maps")
time.sleep(3)
    
city = input('Enter City Name : ')                                         
search = driver.find_element_by_id("searchboxinput")                     
search.clear()                                                             
time.sleep(2)
search.send_keys(city)                                                   
button = driver.find_element_by_id("searchbox-searchbutton")             
button.click()                                                          
time.sleep(3)
try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
              lat = lat_lng_list[0]
              lng = lat_lng_list[1]
              print("Latitude = {}, Longitude = {}".format(lat, lng))
except Exception as e:
         print("Error: ", str(e))
# Out:
# Enter City Name : thalassery
# URL Extracted:  https://www.google.co.in/maps/place/Thalassery,+Kerala/@12.7648443,75.2017164,15z/data=!4m5!3m4!1s0x3ba4265aa19eeb65:0xf5e6181d3e97d10e!8m2!3d11.7491424!4d75.4890346
# Error:  name 're' is not defined

# %% [markdown]
# # Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 – September 20) from trak.in.

# %%
driver=webdriver.Chrome(r'C:\Users\Admin\Downloads\chromedriver.exe')

# %%
driver.get('https://trak.in/')

# %%
button = driver.find_element_by_xpath('//li[@id=\"menu-item-51510\"]/a').get_attribute('href')
driver.get(button)

# %%
fund_dict = {}
fund_dict['Date'] = []
fund_dict['Startup Name'] = []
fund_dict['Industry/Vertical'] = []
fund_dict['Sub-Vertical'] = []
fund_dict['Location'] = []
fund_dict['Investor'] = []
fund_dict['Investment Type'] = []
fund_dict['Amount(in USD)'] = []

# %%
for i in range(48,51):
    driver.find_element_by_xpath('//div[@id=\"tablepress-{}_wrapper\"]/div/label/select/option[4]'.format(i)).click()
    dt = driver.find_elements_by_xpath('//table[@id=\"tablepress-{}\"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        fund_dict['Date'].append(d.text)
    sn = driver.find_elements_by_xpath('//table[@id=\"tablepress-{}\"]/tbody/tr/td[3]'.format(i))
    for n in sn:
        fund_dict['Startup Name'].append(n.text)
    ind = driver.find_elements_by_xpath('//table[@id=\"tablepress-{}\"]/tbody/tr/td[4]'.format(i))
    for n in ind:
        fund_dict['Industry/Vertical'].append(n.text)
    sv = driver.find_elements_by_xpath('//table[@id=\"tablepress-{}\"]/tbody/tr/td[5]'.format(i))
    for s in sv:
        fund_dict['Sub-Vertical'].append(s.text)
    loc = driver.find_elements_by_xpath('//table[@id=\"tablepress-{}\"]/tbody/tr/td[6]'.format(i))
    for l in loc:
        fund_dict['Location'].append(l.text)
    inv = driver.find_elements_by_xpath('//table[@id=\"tablepress-{}\"]/tbody/tr/td[7]'.format(i))
    for n in inv:
        fund_dict['Investor'].append(n.text)
    invt = driver.find_elements_by_xpath('//table[@id=\"tablepress-{}\"]/tbody/tr/td[8]'.format(i))
    for n in invt:
        fund_dict['Investment Type'].append(n.text)
    amt = driver.find_elements_by_xpath('//table[@id=\"tablepress-{}\"]/tbody/tr/td[9]'.format(i))
    for a in amt:
        fund_dict['Amount(in USD)'].append(a.text)
   
    fund_df = pd.DataFrame(fund_dict)
    fund_df

# %%
fund_df
# Out:
#           Date               Startup Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  03/08/2020                 CrowdPouch
# 21  04/08/2020                 DrinkPrime
# 22  08/09/2020                     Byju’s
# 23  12/09/2020                  mCaffeine
# 24  09/09/2020                     Qshala
# 25  02/09/2020                      Winzo
# 26  09/09/2020                Hippo Video
# 27  07/09/2020                    Melorra
# 28  07/09/2020                        1mg
# 29  31/08/2020                      mfine
# 30  31/08/2020                       Apna
# 31  03/09/2020                    Railofy
# 32  08/09/2020            Cell Propulsion
#
#                          Industry/Vertical  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 FinTech
# 21                      Water Purification
# 22                                 EduTech
# 23                           Personal Care
# 24                                 EduTech
# 25                           Online Gaming
# 26  Video Customer Experience(CX) Platform
# 27                              E-commerce
# 28                              E-commerce
# 29                              HealthTech
# 30                         Human Resources
# 31                          Transportation
# 32                              Automobile
#
#                                          Sub-Vertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                 Financial Services
# 21                                 Water Purification
# 22                                    Online Tutoring
# 23                                Skincare & Haircare
# 24                 Online Curiosity Platform for Kids
# 25                                      Online Gaming
# 26             Video Customer Experience(CX) Platform
# 27                               Online Jewelry Store
# 28                                    Online Pharmacy
# 29                      On-Demand Healthcare Services
# 30                               Recruitment Platform
# 31                       WL & RAC protection platform
# 32                        Electric Mobility Solutions
#
#                                       Location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                   Bangalore
# 22                                   Bangalore
# 23                                      Mumbai
# 24                                   Bangalore
# 25                                   New Delhi
# 26  Newark, Delaware, United States of Amercia
# 27                                   Bangalore
# 28                                     Gurgaon
# 29                                   Bangalore
# 30                                   Bangalore
# 31                                      Mumbai
# 32                                   Bangalore
#
#                                              Investor         Investment Type  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20                         Elina Investments Pvt. Ltd                   Angel
# 21                        Sequoia Surge, ON Mauritius            Pre-Series A
# 22  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 23  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 24                                 Rainmatter Capital                   Angel
# 25  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 26  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 27                         Shadow Holdings, Lightbox.          Debt Financing
# 28         Gaja Capital, Tata Capital, Partners Group             In Progress
# 29                                   Caretech Pte Inc                Series B
# 30         Lightspeed India and Sequoia Capital India                Series A
# 31                                  Chiratae Ventures                    Seed
# 32                         growX Ventures and Micelio            pre-Series A
#
#      Amount(in USD)
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20               NA
# 21        2,880,000
# 22      500,000,000
# 23        3,000,000
# 24          370,000
# 25       15,500,000
# 26        4,500,000
# 27   upto 8,900,000
# 28      100,000,000
# 29        5,400,000
# 30        8,000,000
# 31          950,000
# 32               NA
